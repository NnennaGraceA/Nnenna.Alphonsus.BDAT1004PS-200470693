# %% [markdown]
# # Question 1 C#

# %% [markdown]
# # Question 2 C#

# %% [markdown]
# # Question 3 Python
# Housing
# Step 1. Import the necessary libraries
# Step 2. Create 3 differents Series, each of length 100, as follows:
# • The first a random number from 1 to 4
# • The second a random number from 1 to 3
# • The third a random number from 10,000 to 30,000
# Step 3. Create a DataFrame by joinning the Series by column
# Step 4. Change the name of the columns to bedrs, bathrs, price_sqr_meter
# Step 5. Create a one column DataFrame with the values of the 3 Series and assign it
# to 'bigcolumn'
# Step 6. Ops it seems it is going only until index 99. Is it true?
# Step 7. Reindex the DataFrame so it goes from 0 to 299

# %%
# Step 1. Import the necessary libraries
import pandas as pd
import random

# %%
# Step 2. Create 3 differents Series, each of length 100:
   #First create 3 empty series

Series1 = []
Series2 = []
Series3 = []

# using the randint () Method in Python
for lenght in range(100):
    RandomSeries1 = random.randint(1, 4)
    RandomSeries2 = random.randint(1, 3)
    RandomSeries3 = random.randint(10000, 30000)
    
    Series1.append(RandomSeries1)
    Series2.append(RandomSeries2)
    Series3.append(RandomSeries3)

# %%
Series1
# Out:
# [4,
#  1,
#  4,
#  2,
#  1,
#  2,
#  1,
#  1,
#  2,
#  3,
#  2,
#  2,
#  1,
#  3,
#  3,
#  2,
#  3,
#  1,
#  3,
#  4,
#  1,
#  2,
#  4,
#  3,
#  1,
#  4,
#  3,
#  2,
#  2,
#  1,
#  2,
#  1,
#  4,
#  4,
#  3,
#  3,
#  3,
#  2,
#  4,
#  4,
#  3,
#  1,
#  1,
#  1,
#  4,
#  1,
#  1,
#  1,
#  1,
#  4,
#  2,
#  3,
#  2,
#  3,
#  2,
#  4,
#  1,
#  4,
#  1,
#  2,
#  1,
#  4,
#  3,
#  3,
#  2,
#  2,
#  2,
#  4,
#  3,
#  2,
#  3,
#  1,
#  1,
#  4,
#  2,
#  1,
#  4,
#  2,
#  3,
#  1,
#  4,
#  1,
#  2,
#  2,
#  1,
#  3,
#  4,
#  3,
#  3,
#  3,
#  3,
#  1,
#  1,
#  3,
#  1,
#  3,
#  2,
#  4,
#  2,
#  2]

# %%
Series2
# Out:
# [3,
#  1,
#  1,
#  1,
#  1,
#  1,
#  1,
#  3,
#  2,
#  1,
#  2,
#  2,
#  3,
#  2,
#  1,
#  1,
#  1,
#  3,
#  1,
#  3,
#  1,
#  2,
#  1,
#  3,
#  3,
#  2,
#  3,
#  1,
#  3,
#  3,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  3,
#  3,
#  2,
#  2,
#  1,
#  2,
#  3,
#  2,
#  3,
#  2,
#  1,
#  1,
#  1,
#  2,
#  3,
#  2,
#  1,
#  2,
#  2,
#  3,
#  2,
#  2,
#  2,
#  1,
#  3,
#  1,
#  3,
#  1,
#  2,
#  2,
#  2,
#  1,
#  3,
#  2,
#  1,
#  2,
#  2,
#  1,
#  2,
#  1,
#  1,
#  3,
#  3,
#  3,
#  1,
#  1,
#  2,
#  3,
#  3,
#  2,
#  2,
#  2,
#  1,
#  2,
#  1,
#  1,
#  2,
#  2,
#  1,
#  2,
#  1,
#  3,
#  3,
#  1]

# %%
Series3
# Out:
# [22172,
#  17936,
#  16014,
#  16674,
#  28287,
#  20062,
#  18789,
#  11023,
#  29444,
#  25047,
#  27662,
#  16292,
#  13985,
#  23324,
#  24812,
#  16902,
#  18782,
#  15867,
#  15011,
#  22524,
#  17041,
#  24697,
#  22957,
#  10499,
#  20598,
#  27312,
#  29167,
#  11048,
#  19567,
#  12147,
#  14957,
#  15952,
#  13952,
#  16797,
#  27308,
#  26086,
#  22697,
#  26926,
#  17884,
#  17278,
#  10754,
#  25084,
#  20533,
#  20511,
#  16399,
#  28269,
#  15322,
#  28971,
#  10884,
#  28300,
#  27968,
#  14702,
#  26452,
#  10447,
#  14204,
#  27259,
#  21631,
#  13179,
#  27420,
#  25094,
#  22624,
#  14805,
#  28165,
#  20950,
#  10455,
#  16236,
#  14782,
#  20256,
#  25803,
#  12388,
#  16042,
#  24703,
#  12425,
#  15531,
#  22213,
#  12687,
#  28616,
#  11504,
#  15666,
#  26509,
#  14122,
#  14129,
#  22687,
#  14036,
#  23791,
#  17409,
#  29849,
#  24752,
#  27581,
#  18076,
#  23065,
#  12451,
#  27266,
#  25417,
#  20719,
#  27569,
#  17986,
#  13623,
#  14208,
#  29800]

# %%
# using python print() function to print out the lenght and confirm it matches with the length specified

print (len(Series1))
print (len(Series2))
print (len(Series3))
# Out:
# 100
# 100
# 100

# %%
# Step 3. Create a DataFrame by joining the Series by column



#using function df = pd.DataFrame (zip()) to join the 3 series by column
df = pd.DataFrame(zip(Series1, Series2, Series3))
df
# Out:
#     0  1      2
# 0   4  3  22172
# 1   1  1  17936
# 2   4  1  16014
# 3   2  1  16674
# 4   1  1  28287
# .. .. ..    ...
# 95  3  2  27569
# 96  2  1  17986
# 97  4  3  13623
# 98  2  3  14208
# 99  2  1  29800
#
# [100 rows x 3 columns]

# %%
# Step 4. Change the name of the columns to bedrs, bathrs, price_sqr_meter

df = df.rename(columns={0: "bedrs", 1:"bathrs", 2: "price_sqr_meter" })

# %%
df
# Out:
#     bedrs  bathrs  price_sqr_meter
# 0       4       3            22172
# 1       1       1            17936
# 2       4       1            16014
# 3       2       1            16674
# 4       1       1            28287
# ..    ...     ...              ...
# 95      3       2            27569
# 96      2       1            17986
# 97      4       3            13623
# 98      2       3            14208
# 99      2       1            29800
#
# [100 rows x 3 columns]

# %%
# Create a one column DataFrame with the values of the 3 Series and assign it to 'bigcolumn'

df["bigcolumn"] = Series1 + Series2 + Series3

# %%
df
# Out:
#      bedrs  bathrs  price_sqr_meter  bicolumn  bigcolumn
# 0      4.0     3.0          22172.0         4          4
# 1      1.0     1.0          17936.0         1          1
# 2      4.0     1.0          16014.0         4          4
# 3      2.0     1.0          16674.0         2          2
# 4      1.0     1.0          28287.0         1          1
# ..     ...     ...              ...       ...        ...
# 295    NaN     NaN              NaN     27569      27569
# 296    NaN     NaN              NaN     17986      17986
# 297    NaN     NaN              NaN     13623      13623
# 298    NaN     NaN              NaN     14208      14208
# 299    NaN     NaN              NaN     29800      29800
#
# [300 rows x 5 columns]

# %%
# Step 6. Ops it seems it is going only until index 99. Is it true?

# %%
# Step 7. Reindex the DataFrame so it goes from 0 to 299

# %% [markdown]
# # Question 4 Python
# Wind Statistics
# The data have been modified to contain some missing values, identified by NaN.
# Using pandas should make this exercise easier, in particular for the bonus question.
# You should be able to perform all of these operations without using a for loop or
# other looping construct.
# The data in 'wind.data' has the following format:
# Yr Mo Dy RPT VAL ROS KIL SHA BIR DUB CLA MUL CLO BEL
# MAL
# 61 1 1 15.04 14.96 13.17 9.29 NaN 9.87 13.67 10.25 10.83 12.58 18.50 15.04
# 61 1 2 14.71 NaN 10.83 6.50 12.62 7.67 11.50 10.04 9.79 9.67 17.54 13.83
# 61 1 3 18.50 16.88 12.33 10.13 11.17 6.17 11.25 NaN 8.50 7.67 12.75 12.71
# The first three columns are year, month, and day. The remaining 12 columns are
# average windspeeds in knots at 12 locations in Ireland on that day.

# %%
# Step 1. Import the necessary libraries
import datetime
import pandas as pd
import numpy as np

# %%
# Step 2. Import the dataset from this address

WindData_link = "https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/06_Stats/Wind_Stats/wind.data"
df = pd.read_csv(WindData_link)

# %%
df.head()
# Out:
#   Yr Mo Dy   RPT   VAL   ROS   KIL   SHA   BIR   DUB   CLA   MUL   CLO   BEL   MAL
# 0  61  1  1 15.04 14.96 13.17  9.29   NaN  9.87 1...
# 1  61  1  2 14.71   NaN 10.83  6.50 12.62  7.67 1...
# 2  61  1  3 18.50 16.88 12.33 10.13 11.17  6.17 1...
# 3  61  1  4 10.58  6.63 11.75  4.58  4.54  2.88  ...
# 4  61  1  5 13.33 13.25 11.42  6.17 10.71  8.21 1...

# %%
# Format the data
df = pd.read_csv(WindData_link, sep="\s+")

# %%
df.head()
# Out:
#    Yr  Mo  Dy    RPT    VAL    ROS    KIL    SHA   BIR    DUB    CLA    MUL  \
# 0  61   1   1  15.04  14.96  13.17   9.29    NaN  9.87  13.67  10.25  10.83
# 1  61   1   2  14.71    NaN  10.83   6.50  12.62  7.67  11.50  10.04   9.79
# 2  61   1   3  18.50  16.88  12.33  10.13  11.17  6.17  11.25    NaN   8.50
# 3  61   1   4  10.58   6.63  11.75   4.58   4.54  2.88   8.63   1.79   5.83
# 4  61   1   5  13.33  13.25  11.42   6.17  10.71  8.21  11.92   6.54  10.92
#
#      CLO    BEL    MAL
# 0  12.58  18.50  15.04
# 1   9.67  17.54  13.83
# 2   7.67  12.75  12.71
# 3   5.88   5.46  10.88
# 4  10.34  12.92  11.83

# %%
# Step 3. Assign it to a variable called data and replace the first 3 columns by a proper datetime index.

#Combining the Yr, Mo and Dy  so as to gate a datetime value

def to_datetime(Yr, Mo, Dy):
    dt = f"19{int(Yr)}-{int(Mo)}-{int(Dy)}"
    return dt

# %%
df["datetime"] = df.apply(lambda x: to_datetime(x['Yr'], x['Mo'], x['Dy']), axis=1)


df.drop(["Yr","Mo", "Dy"], axis = 1, inplace = True)

# %%
df.head()
# Out:
#      RPT    VAL    ROS    KIL    SHA   BIR    DUB    CLA    MUL    CLO    BEL  \
# 0  15.04  14.96  13.17   9.29    NaN  9.87  13.67  10.25  10.83  12.58  18.50
# 1  14.71    NaN  10.83   6.50  12.62  7.67  11.50  10.04   9.79   9.67  17.54
# 2  18.50  16.88  12.33  10.13  11.17  6.17  11.25    NaN   8.50   7.67  12.75
# 3  10.58   6.63  11.75   4.58   4.54  2.88   8.63   1.79   5.83   5.88   5.46
# 4  13.33  13.25  11.42   6.17  10.71  8.21  11.92   6.54  10.92  10.34  12.92
#
#      MAL  datetime
# 0  15.04  1961-1-1
# 1  13.83  1961-1-2
# 2  12.71  1961-1-3
# 3  10.88  1961-1-4
# 4  11.83  1961-1-5

# %%
# Step 4. Year 2061? Do we really have data from this year? Create a function to fix it and apply it.

# %%
# Step 5. Set the right dates as the index. Pay attention at the data type, it should be datetime64[ns].

# reference: https://stackoverflow.com/questions/29206612/difference-between-data-type-datetime64ns-and-m8ns

print(df["datetime"].dtypes)
df.set_index('datetime', inplace=True)
# Out:
# object

# %%
df.head()
# Out:
#             RPT    VAL    ROS    KIL    SHA   BIR    DUB    CLA    MUL    CLO  \
# datetime
# 1961-1-1  15.04  14.96  13.17   9.29    NaN  9.87  13.67  10.25  10.83  12.58
# 1961-1-2  14.71    NaN  10.83   6.50  12.62  7.67  11.50  10.04   9.79   9.67
# 1961-1-3  18.50  16.88  12.33  10.13  11.17  6.17  11.25    NaN   8.50   7.67
# 1961-1-4  10.58   6.63  11.75   4.58   4.54  2.88   8.63   1.79   5.83   5.88
# 1961-1-5  13.33  13.25  11.42   6.17  10.71  8.21  11.92   6.54  10.92  10.34
#
#             BEL    MAL
# datetime
# 1961-1-1  18.50  15.04
# 1961-1-2  17.54  13.83
# 1961-1-3  12.75  12.71
# 1961-1-4   5.46  10.88
# 1961-1-5  12.92  11.83

# %%
# Step 6. Compute how many values are missing for each location over the entire record.They should be ignored in all calculations below.

MissingValues = df.isnull().sum()
MissingValues
# Out:
# RPT    6
# VAL    3
# ROS    2
# KIL    5
# SHA    2
# BIR    0
# DUB    3
# CLA    2
# MUL    3
# CLO    1
# BEL    0
# MAL    4
# dtype: int64

# %%
# Step 7. Compute how many non-missing values there are in total.


NonMissingValues = df.notnull().sum().sum()
NonMissingValues
# Out:
# 78857

# %%
#Step 8. Calculate the mean windspeeds of the windspeeds over all the locations and all the times.
         # A single number for the entire dataset.
    
df.mean().mean()
# Out:
# 10.227982360836924

# %%
# Step 9. Create a DataFrame called loc_stats and calculate the min, max and mean windspeeds and standard deviations of the windspeeds at each location over all the days
          # A different set of numbers for each location.

loc_stats = df.describe()
loc_stats
# Out:
#                RPT          VAL          ROS          KIL          SHA  \
# count  6568.000000  6571.000000  6572.000000  6569.000000  6572.000000
# mean     12.362987    10.644314    11.660526     6.306468    10.455834
# std       5.618413     5.267356     5.008450     3.605811     4.936125
# min       0.670000     0.210000     1.500000     0.000000     0.130000
# 25%       8.120000     6.670000     8.000000     3.580000     6.750000
# 50%      11.710000    10.170000    10.920000     5.750000     9.960000
# 75%      15.920000    14.040000    14.670000     8.420000    13.540000
# max      35.800000    33.370000    33.840000    28.460000    37.540000
#
#                BIR          DUB          CLA          MUL          CLO  \
# count  6574.000000  6571.000000  6572.000000  6571.000000  6573.000000
# mean      7.092254     9.797343     8.495053     8.493590     8.707332
# std       3.968683     4.977555     4.499449     4.166872     4.503954
# min       0.000000     0.000000     0.000000     0.000000     0.040000
# 25%       4.000000     6.000000     5.090000     5.370000     5.330000
# 50%       6.830000     9.210000     8.080000     8.170000     8.290000
# 75%       9.670000    12.960000    11.420000    11.190000    11.630000
# max      26.160000    30.370000    31.080000    25.880000    28.210000
#
#                BEL          MAL
# count  6574.000000  6570.000000
# mean     13.121007    15.599079
# std       5.835037     6.699794
# min       0.130000     0.670000
# 25%       8.710000    10.710000
# 50%      12.500000    15.000000
# 75%      16.880000    19.830000
# max      42.380000    42.540000

# %%
# Step 10. Create a DataFrame called day_stats and calculate the min, max and mean windspeed and standard deviations of the windspeeds across all the locations at each day.
           # A different set of numbers for each day
    
# Get the statistical record of the data  
day_stats = df.apply(pd.DataFrame.describe, axis=1)
day_stats.head()
# Out:
#           count       mean       std   min      25%     50%      75%    max
# datetime
# 1961-1-1   11.0  13.018182  2.808875  9.29  10.5400  13.170  15.0000  18.50
# 1961-1-2   11.0  11.336364  3.188994  6.50   9.7300  10.830  13.2250  17.54
# 1961-1-3   11.0  11.641818  3.681912  6.17   9.3150  11.250  12.7300  18.50
# 1961-1-4   12.0   6.619167  3.198126  1.79   4.5700   5.855   9.1175  11.75
# 1961-1-5   12.0  10.630000  2.445356  6.17   9.8075  11.170  12.1700  13.33

# %%
for i, month in enumerate(pd.Series(df.index).map(lambda x:pd._libs.tslibs.timestamps.Timestamp(x)).dt.month_name().unique(), 3):

    x = (pd.Series(pd.Series(df.index).map(lambda x:pd._libs.tslibs.timestamps.Timestamp(x)).dt.month == (i+1))).astype(int)
    x.index = df.index
    df[month]=x
df
# Out:
#               RPT    VAL    ROS    KIL    SHA    BIR    DUB    CLA    MUL  \
# datetime
# 1961-1-1    15.04  14.96  13.17   9.29    NaN   9.87  13.67  10.25  10.83
# 1961-1-2    14.71    NaN  10.83   6.50  12.62   7.67  11.50  10.04   9.79
# 1961-1-3    18.50  16.88  12.33  10.13  11.17   6.17  11.25    NaN   8.50
# 1961-1-4    10.58   6.63  11.75   4.58   4.54   2.88   8.63   1.79   5.83
# 1961-1-5    13.33  13.25  11.42   6.17  10.71   8.21  11.92   6.54  10.92
# ...           ...    ...    ...    ...    ...    ...    ...    ...    ...
# 1978-12-27  17.58  16.96  17.62   8.08  13.21  11.67  14.46  15.59  14.04
# 1978-12-28  13.21   5.46  13.46   5.00   8.12   9.42  14.33  16.25  15.25
# 1978-12-29  14.00  10.29  14.42   8.71   9.71  10.54  19.17  12.46  14.50
# 1978-12-30  18.50  14.04  21.29   9.13  12.75   9.71  18.08  12.87  12.46
# 1978-12-31  20.33  17.41  27.29   9.59  12.08  10.13  19.25  11.63  11.58
#
#               CLO  ...  March  April  May  June  July  August  September  \
# datetime           ...
# 1961-1-1    12.58  ...      0      0    0     0     0       0          0
# 1961-1-2     9.67  ...      0      0    0     0     0       0          0
# 1961-1-3     7.67  ...      0      0    0     0     0       0          0
# 1961-1-4     5.88  ...      0      0    0     0     0       0          0
# 1961-1-5    10.34  ...      0      0    0     0     0       0          0
# ...           ...  ...    ...    ...  ...   ...   ...     ...        ...
# 1978-12-27  14.00  ...      0      0    0     0     0       0          1
# 1978-12-28  18.05  ...      0      0    0     0     0       0          1
# 1978-12-29  16.42  ...      0      0    0     0     0       0          1
# 1978-12-30  12.12  ...      0      0    0     0     0       0          1
# 1978-12-31  11.38  ...      0      0    0     0     0       0          1
#
#             October  November  December
# datetime
# 1961-1-1          0         0         0
# 1961-1-2          0         0         0
# 1961-1-3          0         0         0
# 1961-1-4          0         0         0
# 1961-1-5          0         0         0
# ...             ...       ...       ...
# 1978-12-27        0         0         0
# 1978-12-28        0         0         0
# 1978-12-29        0         0         0
# 1978-12-30        0         0         0
# 1978-12-31        0         0         0
#
# [6574 rows x 24 columns]

# %% [markdown]
# # Question 5 Python

# %%
# Step 1. Import the necessary libraries


import datetime
import pandas as pd
import numpy as np

# %%
# Step 2. Import the dataset from this address.

Link = "https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv"

# %%
# Step 3. Assign it to a variable called chipo.

chipo = pd.read_csv(Link, sep='\t')

# %%
# Step 4. See the first 10 entries

chipo.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
# 5  [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...    $10.98
# 6                                                NaN     $1.69
# 7  [Tomatillo Red Chili Salsa, [Fajita Vegetables...    $11.75
# 8  [Tomatillo Green Chili Salsa, [Pinto Beans, Ch...     $9.25
# 9  [Fresh Tomato Salsa, [Rice, Black Beans, Pinto...     $9.25

# %%
# Step 5. What is the number of observations in the dataset?

NoOfObservations = chipo.shape[0]
print (NoOfObservations)
# Out:
# 4622

# %%
# Step 6. What is the number of columns in the dataset?
NoOfColumns = chipo.shape[1]
print (NoOfColumns)
# Out:
# 5

# %%
# Step 7. Print the name of all the columns.

print(chipo.columns.values)
# Out:
# ['order_id' 'quantity' 'item_name' 'choice_description' 'item_price']

# %%
# Step 8. How is the dataset indexed?

data = pd.Series(['order_id', 'quantity', 'item_name', 'choice_description', 'item_price'],
                 index=['N', 'G', 'A', 'L', 'P'])
data
# Out:
# N              order_id
# G              quantity
# A             item_name
# L    choice_description
# P            item_price
# dtype: object

# %%
# Step 9. Which was the most-ordered item?

order_qty = chipo.groupby(['item_name'])[['item_name','quantity']].sum()
order_qty
# Out:
#                                        quantity
# item_name
# 6 Pack Soft Drink                            55
# Barbacoa Bowl                                66
# Barbacoa Burrito                             91
# Barbacoa Crispy Tacos                        12
# Barbacoa Salad Bowl                          10
# Barbacoa Soft Tacos                          25
# Bottled Water                               211
# Bowl                                          4
# Burrito                                       6
# Canned Soda                                 126
# Canned Soft Drink                           351
# Carnitas Bowl                                71
# Carnitas Burrito                             60
# Carnitas Crispy Tacos                         8
# Carnitas Salad                                1
# Carnitas Salad Bowl                           6
# Carnitas Soft Tacos                          40
# Chicken Bowl                                761
# Chicken Burrito                             591
# Chicken Crispy Tacos                         50
# Chicken Salad                                 9
# Chicken Salad Bowl                          123
# Chicken Soft Tacos                          120
# Chips                                       230
# Chips and Fresh Tomato Salsa                130
# Chips and Guacamole                         506
# Chips and Mild Fresh Tomato Salsa             1
# Chips and Roasted Chili Corn Salsa           23
# Chips and Roasted Chili-Corn Salsa           18
# Chips and Tomatillo Green Chili Salsa        45
# Chips and Tomatillo Red Chili Salsa          50
# Chips and Tomatillo-Green Chili Salsa        33
# Chips and Tomatillo-Red Chili Salsa          25
# Crispy Tacos                                  2
# Izze                                         20
# Nantucket Nectar                             29
# Salad                                         2
# Side of Chips                               110
# Steak Bowl                                  221
# Steak Burrito                               386
# Steak Crispy Tacos                           36
# Steak Salad                                   4
# Steak Salad Bowl                             31
# Steak Soft Tacos                             56
# Veggie Bowl                                  87
# Veggie Burrito                               97
# Veggie Crispy Tacos                           1
# Veggie Salad                                  6
# Veggie Salad Bowl                            18
# Veggie Soft Tacos                             8

# %%
# Step 10. For the most-ordered item, how many items were ordered?

most_ordered = order_qty[order_qty.quantity == order_qty.quantity.max()]
most_ordered
# Out:
#     index     item_name  quantity
# 17     17  Chicken Bowl       761

# %%
# Step 11. What was the most ordered item in the choice_description column?

order_qty = chipo.groupby(['choice_description'])[['choice_description','quantity']].sum()
order_qty
# Out:
#                                                     quantity
# choice_description
# [Adobo-Marinated and Grilled Chicken, Pinto Bea...         1
# [Adobo-Marinated and Grilled Chicken, [Sour Cre...         1
# [Adobo-Marinated and Grilled Chicken]                      1
# [Adobo-Marinated and Grilled Steak, [Sour Cream...         1
# [Adobo-Marinated and Grilled Steak]                        1
# ...                                                      ...
# [[Tomatillo-Red Chili Salsa (Hot), Tomatillo-Gr...         2
# [[Tomatillo-Red Chili Salsa (Hot), Tomatillo-Gr...         1
# [[Tomatillo-Red Chili Salsa (Hot), Tomatillo-Gr...         1
# [[Tomatillo-Red Chili Salsa (Hot), Tomatillo-Gr...         1
# [[Tomatillo-Red Chili Salsa (Hot), Tomatillo-Gr...         1
#
# [1043 rows x 1 columns]

# %%
most_ordered = order_qty[order_qty.quantity == order_qty.quantity.max()]
most_ordered
# Out:
#                     quantity
# choice_description
# [Diet Coke]              159

# %%
# Step 12. How many items were orderd in total?

order_qty['quantity'].sum()
# Out:
# 3590

# %% [markdown]
# #  Step 13.
#       • Turn the item price into a float
#       • Check the item price type
#       • Create a lambda function and change the type of item price
#       • Check the item price type

# %%
#  • Check the item price type

print(chipo['item_price'].dtypes)
# Out:
# object

# %%
# • Turn the item price into a float

def turn_to_float(dollar_value):
    price = dollar_value[1:]
    price_float = float(price)
    return price_float

res = turn_to_float("$4.05")
res
# Out:
# 4.05

# %%
#  • Create a lambda function and change the type of item price

chipo['item_price'] = chipo.apply(lambda x: 
                                  turn_to_float(x['item_price']), axis=1)
chipo.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description  item_price
# 0                                                NaN        2.39
# 1                                       [Clementine]        3.39
# 2                                            [Apple]        3.39
# 3                                                NaN        2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98

# %%
#  • Check the item price type

print(chipo['item_price'].dtypes)
# Out:
# float64

# %%
# Step 14. How much was the revenue for the period in the dataset?

revenue = (chipo['quantity']*chipo['item_price']).sum()
revenue
# Out:
# 39237.02

# %%
# Step 15. How many orders were made in the period?

no_of_orders = chipo['quantity'].sum()
no_of_orders
# Out:
# 4972

# %%
# Step 16. What is the average revenue amount per order?


avg_rev_per_ord = (revenue/no_of_orders)
avg_rev_per_ord
# Out:
# 7.8915969428801285

# %%
# Step 17. How many different items are sold?

chipo['item_name'].nunique()
# Out:
# 50

# %%
# Listing the 50 different items sold

chipo['item_name'].value_counts()
# Out:
# Chicken Bowl                             726
# Chicken Burrito                          553
# Chips and Guacamole                      479
# Steak Burrito                            368
# Canned Soft Drink                        301
# Chips                                    211
# Steak Bowl                               211
# Bottled Water                            162
# Chicken Soft Tacos                       115
# Chips and Fresh Tomato Salsa             110
# Chicken Salad Bowl                       110
# Canned Soda                              104
# Side of Chips                            101
# Veggie Burrito                            95
# Barbacoa Burrito                          91
# Veggie Bowl                               85
# Carnitas Bowl                             68
# Barbacoa Bowl                             66
# Carnitas Burrito                          59
# Steak Soft Tacos                          55
# 6 Pack Soft Drink                         54
# Chips and Tomatillo Red Chili Salsa       48
# Chicken Crispy Tacos                      47
# Chips and Tomatillo Green Chili Salsa     43
# Carnitas Soft Tacos                       40
# Steak Crispy Tacos                        35
# Chips and Tomatillo-Green Chili Salsa     31
# Steak Salad Bowl                          29
# Nantucket Nectar                          27
# Barbacoa Soft Tacos                       25
# Chips and Roasted Chili Corn Salsa        22
# Chips and Tomatillo-Red Chili Salsa       20
# Izze                                      20
# Veggie Salad Bowl                         18
# Chips and Roasted Chili-Corn Salsa        18
# Barbacoa Crispy Tacos                     11
# Barbacoa Salad Bowl                       10
# Chicken Salad                              9
# Carnitas Crispy Tacos                      7
# Veggie Soft Tacos                          7
# Veggie Salad                               6
# Burrito                                    6
# Carnitas Salad Bowl                        6
# Steak Salad                                4
# Crispy Tacos                               2
# Salad                                      2
# Bowl                                       2
# Carnitas Salad                             1
# Veggie Crispy Tacos                        1
# Chips and Mild Fresh Tomato Salsa          1
# Name: item_name, dtype: int64

# %% [markdown]
# # Question 6 Python
# Create a line plot showing the number of marriages and divorces per capita in the U.S. between 1867 and 2014. Label both lines and show the legend.
# Don't forget to label your axes!

# %%
import pandas as pd
print(pd.__version__)
import matplotlib.pyplot as plt
from matplotlib.axis import Axis 
import numpy as np
# Out:
# 1.0.5

# %%
# Import and define data

USMarriageLink = "C:/Users/HP/Downloads/us-marriages-divorces-1867-2014.csv"
df = pd.read_csv(USMarriageLink)
df.set_index('Year', inplace=True)

# %%
ax = df.plot(lw=3, colormap='viridis', figsize =(15,8), marker='.', markersize=5, title= "NUMBER OF MARRIAGES & DIVORCES PER CAPITA IN THE U.S")
ax.set_xlabel("Year")
ax.set_ylabel("Divorce and Marriage per capita")
# Out:
# Text(0, 0.5, 'Divorce and Marriage per capita')

# %% [markdown]
# # Question 7 Python
# Create a vertical bar chart comparing the number of marriages and divorces per capita in the U.S. between 1900, 1950, and 2000.
# Don't forget to label your axes!

# %%
new_df = marriage_df[marriage_df.index.isin([1900, 1950,2000])]
new_df
# Out:
#       Marriages  Divorces  Population  Marriages_per_1000  Divorces_per_1000
# Year
# 1900   709000.0   56000.0    76094000                 9.3                0.7
# 1950  1667000.0  385000.0   151684000                11.0                2.5
# 2000  2315000.0  944000.0   282398000                 8.2                3.3

# %%
new_df[["Marriages_per_1000", "Divorces_per_1000"]].plot(kind='bar', colormap='plasma', figsize =(15,8))
ax.set_xlabel("Year")
ax.set_ylabel("Divorce and Marriage per capita")
# Out:
# Text(17.200000000000017, 0.5, 'Divorce and Marriage per capita')

# %% [markdown]
# # Question 8 Python
# Create a horizontal bar chart that compares the deadliest actors in Hollywood. Sort
# the actors by their kill count and label each bar with the corresponding actor's name.
# Don't forget to label your axes!

# %%
# Import and define data

ActorsLink = "C:/Users/HP/Downloads/actor_kill_counts.csv"
df = pd.read_csv(ActorsLink)
df
# Out:
#                    Actor  Count
# 0  Arnold Schwarzenegger    369
# 1           Chow Yun-Fat    295
# 2         Clint Eastwood    207
# 3             Clive Owen    194
# 4         Dolph Lundgren    239
# 5                 Jet Li    201
# 6           Nicolas Cage    204
# 7     Sylvester Stallone    267
# 8    Tomisaburo Wakayama    226
# 9          Wesley Snipes    193

# %%
import random
# %matplotlib inline

# %%
df.plot(kind='barh', colormap='autumn', figsize =(15,8))

#tried to label x and y axes and I got an error that rectangle object has no property xlabel and ylabel

# %% [markdown]
# # Question 9 Python
# Create a pie chart showing the fraction of all Roman Emperors that were
# assassinated.
# Make sure that the pie chart is an even circle, labels the categories, and shows the
# percentage breakdown of the categories.

# %%
# Import csv file and define data

RomanEmperors = "C:/Users/HP/Downloads/roman-emperor-reigns.csv"
df = pd.read_csv(RomanEmperors)
df.head()
# Out:
#     Emperor  Length_of_Reign         Cause_of_Death
# 0  Augustus            40.58  Possibly assassinated
# 1  Tiberius            22.50  Possibly assassinated
# 2  Caligula             4.83           Assassinated
# 3  Claudius            13.75  Possibly assassinated
# 4      Nero            13.67                Suicide

# %%
import matplotlib.pyplot as plotter

# %%
values_count = df["Cause_of_Death"].value_counts()
values_count.plot(kind='pie', colormap = 'hot', autopct='%1.0f%%', figsize =(15,8))

# %% [markdown]
# # Question 10 Python
# Create a scatter plot showing the relationship between the total revenue earned by
# arcades and the number of Computer Science PhDs awarded in the U.S. between
# 2000 and 2009.
# Don't forget to label your axes!
# Color each dot according to its year.

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
Arcade= "C:/Users/HP/Downloads/arcade-revenue-vs-cs-doctorates.csv"
df = pd.read_csv(Arcade)

# %%
df
# Out:
#    Year  Total Arcade Revenue (billions)  \
# 0  2000                            1.196
# 1  2001                            1.176
# 2  2002                            1.269
# 3  2003                            1.240
# 4  2004                            1.307
# 5  2005                            1.435
# 6  2006                            1.601
# 7  2007                            1.654
# 8  2008                            1.803
# 9  2009                            1.734
#
#    Computer Science Doctorates Awarded (US)
# 0                                       861
# 1                                       830
# 2                                       809
# 3                                       867
# 4                                       948
# 5                                      1129
# 6                                      1453
# 7                                      1656
# 8                                      1787
# 9                                      1611

# %%
df.columns =['Years', 'Total_Arcade_Revenue', 'Computer_Science_PhDs_Awarded']

# %%
df
# Out:
#    Years  Total_Arcade_Revenue  Computer_Science_PhDs_Awarded
# 0   2000                 1.196                            861
# 1   2001                 1.176                            830
# 2   2002                 1.269                            809
# 3   2003                 1.240                            867
# 4   2004                 1.307                            948
# 5   2005                 1.435                           1129
# 6   2006                 1.601                           1453
# 7   2007                 1.654                           1656
# 8   2008                 1.803                           1787
# 9   2009                 1.734                           1611

# %%
# %matplotlib inline
x1='Years'
y1='Total_Arcade_Revenue'
x2='Years'
y2='Computer_Science_PhDs_Awarded'
figsize =(10,10)

# %%
#g =sns.scatterplot(x='Total_Arcade_Revenue', y = 'Computer_Science_PhDs_Awarded')
plt.scatter(x1, y1, color = 'red')
plt.scatter(x2, y2, color = 'blue')
plt.title('Relationship Between Total Revenue Earned by Arcades And # of Computer Science PhDs awarded in the U.S')
# Out:
# Text(0.5, 1.0, 'Relationship Between Total Revenue Earned by Arcades And # of Computer Science PhDs awarded in the U.S')

# %%
# %matplotlib inline

df.plot(kind='scatter',x='Years',y='Total_Arcade_Revenue', legend='Years', colormap = 'hot', figsize =(10,10)) # scatter plot
df.plot(kind='scatter',x='Years',y='Computer_Science_PhDs_Awarded', legend='Years', colormap = 'hot', figsize =(10,10)) # scatter plot
plt.legend('Years')
plt.title('Relationship Between Total Revenue Earned by Arcades And # of Computer Science PhDs awarded in the U.S')
# Out:
# Text(0.5, 1.0, 'Relationship Between Total Revenue Earned by Arcades And # of Computer Science PhDs awarded in the U.S')

# %%
# %matplotlib inline

df.plot(kind='scatter', x='Total_Arcade_Revenue', y='Computer_Science_PhDs_Awarded', legend='Years', colormap = 'autumn', figsize =(10,10) )
plt.legend('Years')
plt.title('Relationship Between Total Revenue Earned by Arcades And # of Computer Science PhDs awarded in the U.S')
# Out:
# Text(0.5, 1.0, 'Relationship Between Total Revenue Earned by Arcades And # of Computer Science PhDs awarded in the U.S')
